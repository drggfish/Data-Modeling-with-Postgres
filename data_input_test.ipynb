# %%
import os
import glob
import pandas as pd

# %%
def process_song_file(filepath):
    '''
    Read song metadata from a JSON `filepath` file and insert the data into
    song and artist tables based on different columns.
    Parameters:
    -----------
    cur : psycopg2.cursor
        cursor obtained from active session to execute PostgreSQL commands.
    filepath : str or path object
        path to the song file.
    '''
    # open song file
    df = pd.read_json(filepath, lines=True)

    print(df.head(1))

    # insert song record
    song_data = df.loc[0, ['song_id', 'title', 'artist_id', 'year',
                           'duration']].values.tolist()
    # Change datatype from np.int64 to python's int
    song_data[-2] = int(song_data[-2])

    #print(song_data)

    # insert artist record

    for index, row in df.iterrows():
        # insert song record
        artist_data = row[["artist_id", "artist_name", "artist_location", "artist_latitude", "artist_longitude"]].values
        #print(artist_data)

    artist_data = df.loc[0, ['artist_id', 'artist_name', 'artist_location','artist_latitude', 'artist_longitude']].values.tolist()
    
    #print(artist_data)

# %%
def process_data(filepath, func):
    # get all files matching extension from directory
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))

    # get total number of files found
    num_files = len(all_files)
    print('{} files found in {}'.format(num_files, filepath))

    # iterate over files and process
    for i, datafile in enumerate(all_files, 1):
        func(datafile)

# %%
def main():
    process_data(filepath='data/song_data', func=process_song_file)

# %%
if __name__ == "__main__":
    main()
# Out:
# 71 files found in data/song_data
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
#
#    artist_location artist_name             song_id             title  \
# 0  California - LA      Casual  SOMZWCG12A8C13C480  I Didn't Mean To
#
#     duration  year
# 0  218.93179     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMJAGH1187FB546F3         35.14968         -90.04892
#
#   artist_location   artist_name             song_id      title   duration  \
# 0     Memphis, TN  The Box Tops  SOCIWDW12A8C13D406  Soul Deep  148.03546
#
#    year
# 0  1969
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARKRRTF1187B9984DA              NaN               NaN
#
#   artist_location       artist_name             song_id            title  \
# 0                  Sonora Santanera  SOXVLOJ12AB0189215  Amor De Cabaret
#
#     duration  year
# 0  177.47546     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR7G5I41187FB4CE6C              NaN               NaN
#
#    artist_location artist_name             song_id            title  \
# 0  London, England    Adam Ant  SONHOTT12A8C13493C  Something Girls
#
#     duration  year
# 0  233.40363  1982
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARXR32B1187FB57099              NaN               NaN
#
#   artist_location artist_name             song_id           title   duration  \
# 0                         Gob  SOFSOCN12A8C143F5D  Face the Ashes  209.60608
#
#    year
# 0  2007
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARKFYS91187B98E58F              NaN               NaN
#
#   artist_location            artist_name             song_id  \
# 0                  Jeff And Sheri Easter  SOYMRWW12A6D4FAB14
#
#                                          title  duration  year
# 0  The Moon And I (Ordinary Day Album Version)  267.7024     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD0S291187B9B7BF5              NaN               NaN
#
#   artist_location artist_name             song_id                  title  \
# 0            Ohio     Rated R  SOMJBYD12A6D4F8557  Keepin It Real (Skit)
#
#     duration  year
# 0  114.78159     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR10USD1187B99F3F1              NaN               NaN
#
#                artist_location            artist_name             song_id  \
# 0  Burlington, Ontario, Canada  Tweeterfriendly Music  SOHKNRJ12A6701D1F8
#
#           title   duration  year
# 0  Drop of Rain  189.57016     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR8ZCNI1187B9A069B              NaN               NaN
#
#   artist_location       artist_name             song_id       title  \
# 0                  Planet P Project  SOIAZJW12AB01853F1  Pink World
#
#     duration  year
# 0  269.81832  1984
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARNTLGG11E2835DDB9              NaN               NaN
#
#   artist_location artist_name             song_id  \
# 0                         Clp  SOUDSGM12AC9618304
#
#                                title   duration  year
# 0  Insatiable (Instrumental Version)  266.39628     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARGSJW91187B9B1D6B         35.21962         -80.01955
#
#   artist_location   artist_name             song_id            title  \
# 0  North Carolina  JennyAnyKind  SOQHXMF12AB0182363  Young Boy Blues
#
#     duration  year
# 0  218.77506     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARC43071187B990240              NaN               NaN
#
#   artist_location   artist_name             song_id                     title  \
# 0      Wisner, LA  Wayne Watson  SOKEJEJ12A8C13E0D0  The Urgency (LP Version)
#
#     duration  year
# 0  245.21098     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARL7K851187B99ACD2              NaN               NaN
#
#   artist_location artist_name             song_id     title   duration  year
# 0                   Andy Andy  SOMUYGI12AB0188633  La Culpa  226.35057     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARHHO3O1187B989413              NaN               NaN
#
#   artist_location artist_name             song_id           title   duration  \
# 0                   Bob Azzam  SORAMLE12AB017C8B0  Auguri Cha Cha  191.84281
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARIK43K1187B9AE54C              NaN               NaN
#
#      artist_location    artist_name             song_id  \
# 0  Beverly Hills, CA  Lionel Richie  SOBONFF12A6D4F84D8
#
#                      title  duration  year
# 0  Tonight Will Be Alright  307.3824  1986
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD842G1187B997376         43.64856         -79.38533
#
#             artist_location artist_name             song_id     title  \
# 0  Toronto, Ontario, Canada  Blue Rodeo  SOHUOAP12A8AE488E9  Floating
#
#     duration  year
# 0  491.12771  1987
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARIG6O41187B988BDD         37.16793         -95.84502
#
#   artist_location      artist_name             song_id      title  duration  \
# 0   United States  Richard Souther  SOUQQEA12A8C134B1B  High Tide  228.5971
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR1ZHYZ1187FB3C717              NaN               NaN
#
#   artist_location    artist_name             song_id                 title  \
# 0                  Faiz Ali Faiz  SOILPQQ12AB017E82A  Sohna Nee Sohna Data
#
#     duration  year
# 0  599.24853     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARYKCQI1187FB3B18F              NaN               NaN
#
#   artist_location artist_name             song_id              title  \
# 0                       Tesla  SOXLBJT12A8C140925  Caught In A Dream
#
#     duration  year
# 0  290.29832  2004
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARNPAGP1241B9C7FD4              NaN               NaN
#
#   artist_location artist_name             song_id            title   duration  \
# 0                   lextrical  SOZVMJI12AB01808AF  Synthetic Dream  165.69424
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARQGYP71187FB44566         34.31109         -94.02978
#
#   artist_location   artist_name             song_id  \
# 0     Mineola, AR  Jimmy Wakely  SOWTBJW12AC468AC6E
#
#                         title   duration  year
# 0  Broken-Down Merry-Go-Round  151.84934     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARI3BMM1187FB4255E          38.8991           -77.029
#
#   artist_location   artist_name             song_id         title   duration  \
# 0      Washington  Alice Stuart  SOBEBDG12A58A76D60  Kassie Jones  220.78649
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR5KOSW1187FB35FF4         49.80388          15.47491
#
#   artist_location artist_name             song_id           title   duration  \
# 0       Dubai UAE       Elena  SOZCTXZ12AB0182364  Setanta matins  269.58322
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMAC4T1187FB3FA4C         40.82624         -74.47995
#
#      artist_location                artist_name             song_id  \
# 0  Morris Plains, NJ  The Dillinger Escape Plan  SOBBUGU12A8C13E95D
#
#                              title   duration  year
# 0  Setting Fire to Sleeping Giants  207.77751  2004
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR47JEX1187B995D81         37.83721         -94.35868
#
#   artist_location   artist_name             song_id  \
# 0      Nevada, MO  SUE THOMPSON  SOBLGCN12AB0183212
#
#                             title   duration  year
# 0  James (Hold The Ladder Steady)  124.86485  1985
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARGIWFO1187B9B55B7              NaN               NaN
#
#   artist_location     artist_name             song_id                  title  \
# 0                  Five Bolt Main  SOPSWQW12A6D4F8781  Made Like This (Live)
#
#     duration  year
# 0  225.09669     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARNTLGG11E2835DDB9              NaN               NaN
#
#   artist_location artist_name             song_id              title  \
# 0                         Clp  SOZQDIU12A58A7BCF6  Superconfidential
#
#     duration  year
# 0  338.31138     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARDNS031187B9924F0         32.67828         -83.22295
#
#   artist_location artist_name             song_id  \
# 0         Georgia  Tim Wilson  SONYPOM12A8C13B2D7
#
#                                                title   duration  year
# 0  I Think My Wife Is Running Around On Me (Taco ...  186.48771  2005
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AROUOZZ1187B9ABE51         40.79195         -73.94512
#
#                  artist_location  artist_name             song_id  \
# 0  New York, NY [Spanish Harlem]  Willie Bobo  SOBZBAZ12A6D4F8742
#
#             title   duration  year
# 0  Spanish Grease  168.25424  1997
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARH4Z031187B9A71F2         40.73197         -74.17418
#
#   artist_location artist_name             song_id                 title  \
# 0      Newark, NJ  Faye Adams  SOVYKGO12AB0187199  Crazy Mixed Up World
#
#     duration  year
# 0  156.39465  1961
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARB29H41187B98F0EF         41.88415         -87.63241
#
#   artist_location    artist_name             song_id  \
# 0         Chicago  Terry Callier  SOGNCJP12A58A80271
#
#                           title   duration  year
# 0  Do You Finally Need A Friend  342.56934  1972
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR1Y2PT1187FB5B9CE         27.94017         -82.32547
#
#   artist_location  artist_name             song_id              title  \
# 0         Brandon  John Wesley  SOLLHMX12AB01846DC  The Emperor Falls
#
#     duration  year
# 0  484.62322     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARAJPHH1187FB5566A          40.7038         -73.83168
#
#   artist_location      artist_name             song_id            title  \
# 0      Queens, NY  The Shangri-Las  SOYTPEP12AB0180E7B  Twist and Shout
#
#     duration  year
# 0  164.80608  1964
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR0RCMP1187FB3F427         30.08615         -94.10158
#
#   artist_location       artist_name             song_id  \
# 0    Beaumont, TX  Billie Jo Spears  SOGXHEG12AB018653E
#
#                         title   duration  year
# 0  It Makes No Difference Now  133.32853  1992
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AREBBGV1187FB523D2              NaN               NaN
#
#   artist_location                                   artist_name  \
# 0     Houston, TX  Mike Jones (Featuring CJ_ Mello & Lil' Bran)
#
#               song_id                            title   duration  year
# 0  SOOLYAZ12A6701F4A6  Laws Patrolling (Album Version)  173.66159     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARGUVEV1187B98BA17              NaN               NaN
#
#   artist_location     artist_name             song_id              title  \
# 0                  Sierra Maestra  SOGOSOV12AF72A285E  ¿Dónde va Chichi?
#
#     duration  year
# 0  313.12934  1997
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARD7TVE1187B99BFB1              NaN               NaN
#
#    artist_location artist_name             song_id    title   duration  year
# 0  California - LA      Casual  SOQLGFP12A58A7800E  OAKtown  259.44771     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR3JMC51187B9AE49D         28.53823         -81.37739
#
#   artist_location      artist_name             song_id             title  \
# 0     Orlando, FL  Backstreet Boys  SOPVXLX12A8C1402D5  Larger Than Life
#
#     duration  year
# 0  236.25098  1999
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARPBNLO1187FB3D52F         40.71455         -74.00712
#
#   artist_location artist_name             song_id  \
# 0    New York, NY    Tiny Tim  SOAOIBZ12AB01815BE
#
#                                                title  duration  year
# 0  I Hold Your Hand In Mine [Live At Royal Albert...  43.36281  2000
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR9AWNF1187B9AB0B4              NaN               NaN
#
#            artist_location                   artist_name             song_id  \
# 0  Seattle, Washington USA  Kenny G featuring Daryl Hall  SOZHPGD12A8C1394FE
#
#              title   duration  year
# 0  Baby Come To Me  236.93016     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AROGWRA122988FEE45              NaN               NaN
#
#   artist_location      artist_name             song_id        title  \
# 0                  Christos Dantis  SOSLAVG12A8C13397F  Den Pai Alo
#
#     duration  year
# 0  243.82649     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARMBR4Y1187B9990EB         37.77916        -122.42005
#
#    artist_location   artist_name             song_id                 title  \
# 0  California - SF  David Martin  SOTTDKS12AB018D69B  It Wont Be Christmas
#
#     duration  year
# 0  241.47546     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARQ9BO41187FB5CF1F         40.99471         -77.60454
#
#   artist_location artist_name             song_id                    title  \
# 0    Pennsylvania  John Davis  SOMVWWT12A58A7AE05  Knocked Out Of The Park
#
#     duration  year
# 0  183.17016     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARKULSX1187FB45F84         39.49974        -111.54732
#
#   artist_location artist_name             song_id        title   duration  \
# 0            Utah      Trafik  SOQVMXR12A81C21483  Salt In NYC  424.12363
#
#    year
# 0     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARI2JSK1187FB496EF         51.50632          -0.12714
#
#    artist_location               artist_name             song_id  \
# 0  London, England  Nick Ingman;Gavyn Wright  SODUJBS12A8C132150
#
#                   title   duration  year
# 0  Wessex Loses a Bride  111.62077     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AREDBBQ1187B98AFF5              NaN               NaN
#
#   artist_location    artist_name             song_id  \
# 0                  Eddie Calvert  SOBBXLX12A58A79DDA
#
#                            title   duration  year
# 0  Erica (2005 Digital Remaster)  138.63138     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR7ZKHQ1187B98DD73              NaN               NaN
#
#   artist_location artist_name             song_id              title  \
# 0                        Glad  SOTUKVB12AB0181477  Blessed Assurance
#
#    duration  year
# 0   270.602  1993
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARBGXIG122988F409D         37.77916        -122.42005
#
#    artist_location artist_name             song_id              title  \
# 0  California - SF  Steel Rain  SOOJPRH12A8C141995  Loaded Like A Gun
#
#     duration  year
# 0  173.19138     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR7SMBG1187B9B9066              NaN               NaN
#
#   artist_location  artist_name             song_id               title  \
# 0                  Los Manolos  SOBCOSW12A8C13D398  Rumba De Barcelona
#
#     duration  year
# 0  218.38322     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARGCY1Y1187B9A4FA5         36.16778         -86.77836
#
#   artist_location artist_name             song_id               title  \
# 0  Nashville, TN.    Gloriana  SOQOTLQ12AB01868D0  Clementina Santafè
#
#     duration  year
# 0  153.33832     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR36F9J1187FB406F1         56.27609           9.51695
#
#   artist_location     artist_name             song_id  \
# 0         Denmark  Bombay Rockers  SOBKWDJ12A8C13B2F3
#
#                            title   duration  year
# 0  Wild Rose (Back 2 Basics Mix)  230.71302     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARNNKDK1187B98BBD5         45.80726           15.9676
#
#   artist_location artist_name             song_id  \
# 0  Zagreb Croatia        Jinx  SOFNOQK12AB01840FC
#
#                          title   duration  year
# 0  Kutt Free (DJ Volume Remix)  407.37914     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR62SOJ1187FB47BB5              NaN               NaN
#
#   artist_location     artist_name             song_id      title   duration  \
# 0                  Chase & Status  SOGVQGJ12AB017F169  Ten Tonne  337.68444
#
#    year
# 0  2005
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARBEBBY1187B9B43DB              NaN               NaN
#
#    artist_location artist_name             song_id  \
# 0  Gainesville, FL   Tom Petty  SOFFKZS12AB017F194
#
#                             title   duration  year
# 0  A Higher Place (Album Version)  236.17261  1994
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARDR4AC1187FB371A1              NaN               NaN
#
#   artist_location                                        artist_name  \
# 0                  Montserrat Caballé;Placido Domingo;Vicente Sar...
#
#               song_id                            title   duration  year
# 0  SOBAYLL12A8C138AF9  Sono andati? Fingevo di dormire  511.16363     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARAGB2O1187FB3A161              NaN               NaN
#
#   artist_location                      artist_name             song_id  \
# 0                  Pucho & His Latin Soul Brothers  SOLEYHO12AB0188A85
#
#                 title   duration  year
# 0  Got My Mojo Workin  338.23302     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AREDL271187FB40F44              NaN               NaN
#
#   artist_location   artist_name             song_id  \
# 0                  Soul Mekanik  SOPEGZN12AB0181B3D
#
#                               title  duration  year
# 0  Get Your Head Stuck On Your Neck  45.66159     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARP6N5A1187B99D1A3              NaN               NaN
#
#   artist_location  artist_name             song_id              title  \
# 0   Hamtramck, MI  Mitch Ryder  SOXILUQ12A58A7C72A  Jenny Take a Ride
#
#     duration  year
# 0  207.43791  2004
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARGSAFR1269FB35070              NaN               NaN
#
#   artist_location artist_name             song_id  \
# 0                  Blingtones  SOTCKKY12AB018A141
#
#                          title  duration  year
# 0  Sonnerie lalaleulé hi houuu  29.54404     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARULZCI1241B9C8611              NaN               NaN
#
#   artist_location         artist_name             song_id          title  \
# 0                  Luna Orbit Project  SOSWKAV12AB018FC91  Midnight Star
#
#     duration  year
# 0  335.51628     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR0IAWL1187B9A96D0           8.4177         -80.11278
#
#   artist_location   artist_name             song_id        title   duration  \
# 0          Panama  Danilo Perez  SONSKXP12A8C13A2C9  Native Soul  197.19791
#
#    year
# 0  2003
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARJIE2Y1187B994AB7              NaN               NaN
#
#   artist_location  artist_name             song_id                title  \
# 0                  Line Renaud  SOUPIRU12A6D4FA1E1  Der Kleine Dompfaff
#
#     duration  year
# 0  152.92036     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARLTWXK1187FB5A3F8         32.74863         -97.32925
#
#   artist_location  artist_name             song_id  \
# 0  Fort Worth, TX  King Curtis  SODREIN12A58A7F2E5
#
#                                            title   duration  year
# 0  A Whiter Shade Of Pale (Live @ Fillmore West)  326.00771     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARNF6401187FB57032         40.79086         -73.96644
#
#             artist_location        artist_name             song_id  \
# 0  New York, NY [Manhattan]  Sophie B. Hawkins  SONWXQJ12A8C134D94
#
#                            title  duration  year
# 0  The Ballad Of Sleeping Beauty   305.162  1994
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARPFHN61187FB575F6         41.88415         -87.63241
#
#   artist_location  artist_name             song_id  \
# 0     Chicago, IL  Lupe Fiasco  SOWQTQZ12A58A7B63E
#
#                                       title   duration  year
# 0  Streets On Fire (Explicit Album Version)  279.97995     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR051KA1187B98B2FF              NaN               NaN
#
#   artist_location artist_name             song_id                  title  \
# 0                       Wilks  SOLYIBD12A8C135045  Music is what we love
#
#     duration  year
# 0  261.51138     0
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR8IEZO1187B99055E              NaN               NaN
#
#   artist_location   artist_name             song_id          title   duration  \
# 0                  Marc Shaiman  SOINLJW12A8C13314C  City Slickers  149.86404
#
#    year
# 0  2008
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AR558FS1187FB45658              NaN               NaN
#
#   artist_location artist_name             song_id  title  duration  year
# 0                     40 Grit  SOGDBUF12A8C140FAA  Intro  75.67628  2003
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARVBRGZ1187FB4675A              NaN               NaN
#
#   artist_location   artist_name             song_id           title  \
# 0                  Gwen Stefani  SORRZGD12A6310DBC3  Harajuku Girls
#
#     duration  year
# 0  290.55955  2004
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  ARWB3G61187FB49404              NaN               NaN
#
#   artist_location  artist_name             song_id      title   duration  year
# 0  Hamilton, Ohio  Steve Morse  SODAUVL12A8C13D184  Prognosis  363.85914  2000
#    num_songs           artist_id  artist_latitude  artist_longitude  \
# 0          1  AREVWGE1187B9B890A          -13.442          -41.9952
#
#   artist_location artist_name             song_id        title   duration  \
# 0       Noci (BA)  Bitter End  SOFCHDR12AB01866EF  Living Hell  282.43546
#
#    year
# 0     0

# %%
# Creating the DataFrame
df = pd.DataFrame({"A":[12, 4, 5, None, 1], 
                   "B":[7, 2, 54, 3, None], 
                   "C":[20, 16, 11, 3, 8], 
                   "D":[14, 3, None, 2, 6]})

# %%
print(df)
# Out:
#       A     B   C     D
# 0  12.0   7.0  20  14.0
# 1   4.0   2.0  16   3.0
# 2   5.0  54.0  11   NaN
# 3   NaN   3.0   3   2.0
# 4   1.0   NaN   8   6.0

# %%
df.loc[1, ['A', 'B']].values.tolist()
# Out:
# [4.0, 2.0]
